# %% [markdown]
# # Data Cleaning Notebook
# ## Week 1: AI Health Predictor Project
#
# This notebook contains data cleaning steps from Week 1.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully")

# %%
# Load data
df = pd.read_csv('data/diabetes.csv')
print(f"Data shape: {df.shape}")
print(df.head())

# %% [markdown]
# ## Data Cleaning Completed
# This notebook is part of Week 1 work.
# For model development, see Week 2 notebooks.
